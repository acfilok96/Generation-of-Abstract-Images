# %% [markdown]
# # Load Libraries

# %%
import os
os.getcwd()
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'animogan.ipynb', 'animo_file_30000.npz', 'combined_gan.png', 'desktop.ini', 'discriminator.png', 'Discriminator_Loss_Graph.png', 'FID Score.ipynb', 'Generate Image.ipynb', 'generator.png', 'Generator_Loss_Graph.png', 'generator_model_2.h5', 'Loss_Graph.png', 'loss_record_2.npz', 'Untitled.ipynb']

# %%
import tensorflow
import numpy as np
from numpy import *

# %% [markdown]
# # Plot Function

# %%
import matplotlib.pyplot as plt
def save_plot(x_input,n=4):
    plt.figure(figsize=(10,7))
    for i in range(n*n):
        plt.subplot(n, n, i+1)
        plt.imshow(x_input[i,:,:,:])
        plt.axis('off')
    plt.savefig("Generated Abstract Images.png")
    plt.show()

# %% [markdown]
# # Load Generator Model

# %%
# load generator model
generator = tensorflow.keras.models.load_model("generator_model_2.h5")
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# # Generate Data

# %%
def generate_latent_points(latent_dim, n_samples):
    x_input = randn(latent_dim * n_samples)
    z_input = x_input.reshape(n_samples, latent_dim)
    z = np.random.randint(0,5,size=(n_samples))
    return [z_input,z]

# %%
from numpy import *
from numpy.random import *

# generated images
latent_dim = 512
n_samples = 100
latent_points, labels = generate_latent_points(latent_dim= latent_dim, n_samples= n_samples)
pred  = generator.predict([latent_points, labels])
# Out:
# 4/4 [==============================] - 6s 1s/step

# %% [markdown]
# # Plot Generated Data

# %%
# Generated images
X1 = pred[:100]
X1 = (X1 + 1)/2.0
save_plot(X1,n=6)
