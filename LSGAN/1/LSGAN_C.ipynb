# %% [markdown]
# ## Environment set up and import Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
with tf.device(device_name):
  print(device_name.split(":")[1]," running . . . ")
# Out:
# GPU  running . . .

# %%
import tensorflow as tf
import os,sys
import numpy as np
import random

random.seed(1)
np.random.seed(1)
tf.random.set_seed(2)

# %%
import os, keras, numpy,tensorflow
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from numpy import *
from numpy.random import *
from keras.datasets.fashion_mnist import load_data
from keras.datasets import mnist
from tensorflow.keras.optimizers import Adam
from keras.models import Model
from keras.layers import *
from tensorflow.keras import initializers

# %% [markdown]
# ## **Discriminator** Model

# %%
def define_discriminator(in_shape=(128,128,3),n_classes=5):

    # input level
    label_layer_1 = Input(shape=(1,), name = "input_label")
    label_layer_2 = Embedding(n_classes, 200)(label_layer_1)
    label_layer_3 = Dense(in_shape[0] * in_shape[1])(label_layer_2)
    label_layer_4 = Reshape((in_shape[0], in_shape[1], 1))(label_layer_3)
    # (128, 128, 1)

    # input image
    input_image = Input(shape=in_shape, name = "input_image")
    # (128, 128, 3)

    concat_layer = Concatenate()([input_image, label_layer_4])
    # (128, 128, 4)

    conv2d_layer_1 = Conv2D(filters = 16, kernel_size = (3,3), strides = (2,2), padding='same')(concat_layer)
    conv2d_layer_1 = LeakyReLU(alpha=0.3)(conv2d_layer_1)
    # (64, 64, 16)

    conv2d_layer_2 = Conv2D(filters = 32, kernel_size = (3,3), strides = (2,2), padding = 'same')(conv2d_layer_1)
    conv2d_layer_2 = LeakyReLU(alpha=0.3)(conv2d_layer_2)
    # (32, 32, 32)

    label_layer_3_1 = Dense(32 * 32)(label_layer_2)
    label_layer_4_1 = Reshape((32, 32, 1))(label_layer_3_1)
    # (32, 32, 1)

    concat_layer_1 = Concatenate()([conv2d_layer_2, label_layer_4_1])
    # (32, 32, 33)

    conv2d_layer_3 = Conv2D(filters = 64, kernel_size = (3,3),  strides = (2,2), padding = 'same')(concat_layer_1)
    conv2d_layer_3 = LeakyReLU(alpha=0.3)(conv2d_layer_3)
    # (16, 16, 64)

    conv2d_layer_4 = Conv2D(filters = 128, kernel_size = (3,3), strides = (2,2), padding = 'same')(conv2d_layer_3)
    conv2d_layer_4 = LeakyReLU(alpha=0.3)(conv2d_layer_4)
    # (8, 8, 128)

    conv2d_layer_5 = Conv2D(filters = 256, kernel_size = (3,3), strides = (2,2), padding = 'same')(conv2d_layer_4)
    conv2d_layer_5 = LeakyReLU(alpha=0.3)(conv2d_layer_5)
    # (4, 4, 256)

    flatten_layer = Flatten()(conv2d_layer_5)
    # (4 * 4 * 256)

    dropout_layer = Dropout(rate=0.4)(flatten_layer)
    # (4 * 4 * 256)

    dense_layer = Dense(128 * 8 * 2, activation='relu')(dropout_layer)
    # (8 * 128 * 2)

    # final layer
    output_layer = Dense(1, activation='linear')(dense_layer)
    # (1,)

    model = Model([input_image,label_layer_1], output_layer)

    opt = Adam(learning_rate= 3e-4, beta_1=0.5)
    model.compile(loss='mse', optimizer=opt, metrics=['accuracy'])
    return model

a = define_discriminator()
a.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_label (InputLayer)       [(None, 1)]          0           []
#
#  embedding (Embedding)          (None, 1, 200)       1000        ['input_label[0][0]']
#
#  dense (Dense)                  (None, 1, 16384)     3293184     ['embedding[0][0]']
#
#  input_image (InputLayer)       [(None, 128, 128, 3  0           []
#                                 )]
#
#  reshape (Reshape)              (None, 128, 128, 1)  0           ['dense[0][0]']
#
#  concatenate (Concatenate)      (None, 128, 128, 4)  0           ['input_image[0][0]',
#                                                                   'reshape[0][0]']
#
#  conv2d (Conv2D)                (None, 64, 64, 16)   592         ['concatenate[0][0]']
#
#  leaky_re_lu (LeakyReLU)        (None, 64, 64, 16)   0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 32)   4640        ['leaky_re_lu[0][0]']
#
#  dense_1 (Dense)                (None, 1, 1024)      205824      ['embedding[0][0]']
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 32, 32, 32)   0           ['conv2d_1[0][0]']
#
#  reshape_1 (Reshape)            (None, 32, 32, 1)    0           ['dense_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 33)   0           ['leaky_re_lu_1[0][0]',
#                                                                   'reshape_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 16, 16, 64)   19072       ['concatenate_1[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 16, 16, 64)   0           ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 8, 8, 128)    73856       ['leaky_re_lu_2[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 8, 8, 128)    0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 4, 4, 256)    295168      ['leaky_re_lu_3[0][0]']
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 4, 4, 256)    0           ['conv2d_4[0][0]']
#
#  flatten (Flatten)              (None, 4096)         0           ['leaky_re_lu_4[0][0]']
#
#  dropout (Dropout)              (None, 4096)         0           ['flatten[0][0]']
#
#  dense_2 (Dense)                (None, 2048)         8390656     ['dropout[0][0]']
#
#  dense_3 (Dense)                (None, 1)            2049        ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 12,286,041
# Trainable params: 12,286,041
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# plot the discriminator model
tf.keras.utils.plot_model(a)

# %% [markdown]
# ## **Generator** Model

# %%
def define_generator(latent_dim = 100, n_classes = 5):

    # input level
    label_layer_1 = Input(shape=(1,), name = "input_label")
    label_layer_2 = Embedding(n_classes, 200)(label_layer_1)
    label_layer_3 = Dense(8 * 8)(label_layer_2)
    label_layer_4 = Reshape((8, 8, 1))(label_layer_3)
    # (8, 8, 1)

    # latent input
    latent_layer = Input(shape=(latent_dim,), name = "input_latent")

    layer_2 = Dense(128 * 8 * 8)(latent_layer)
    layer_2 = Activation("relu")(layer_2)
    layer_2 = Reshape((8, 8, 128))(layer_2)
    layer_2_1 = BatchNormalization(momentum = 0.8)(layer_2)
    # (8, 8, 128)


    concat_layer_1 = Concatenate()([layer_2_1, label_layer_4])
    # (8, 8, 129)

    layer_3 = Conv2DTranspose(filters = 64, kernel_size = (3,3), strides=(2,2), padding='same')(concat_layer_1)
    layer_3 = Conv2D(filters = 64, kernel_size = (3,3), padding='same', kernel_initializer = initializers.RandomNormal(0,0.8))(layer_3)
    layer_3 = BatchNormalization(momentum = 0.8)(layer_3)
    layer_3 = LeakyReLU(alpha=0.4)(layer_3)
    # (16, 16, 64)

    layer_4 = Conv2DTranspose(filters = 64, kernel_size = (3,3), strides=(2,2), padding='same')(layer_3)
    layer_4 = Conv2D(filters = 64, kernel_size = (3,3), padding='same',kernel_initializer = initializers.RandomNormal(0,0.8))(layer_4)
    layer_4 = BatchNormalization(momentum = 0.8)(layer_4)
    layer_4 = LeakyReLU(alpha=0.4)(layer_4)
    # (32, 32, 64)

    # label_layer_2_1 = Embedding(n_classes, 100)(label_layer_1)
    label_layer_3_1 = Dense(32 * 32)(label_layer_2)
    label_layer_4_1 = Reshape((32, 32, 1))(label_layer_3_1)
    # label_layer_5_1 = BatchNormalization(momentum = 0.8)(label_layer_4_1)
    # (32, 32, 1)

    concat_layer_2 = Concatenate()([layer_4, label_layer_4_1])
    # (32, 32, 65)


    layer_5 = Conv2DTranspose(filters = 64, kernel_size = (3,3), strides=(2,2), padding='same')(concat_layer_2)
    layer_5 = Conv2D(filters = 64, kernel_size = (3,3), padding='same',kernel_initializer = initializers.RandomNormal(0,0.8))(layer_5)
    layer_5 = BatchNormalization(momentum = 0.8)(layer_5)
    layer_5 = LeakyReLU(alpha=0.4)(layer_5)
    # (64, 64, 64)

    layer_6 = Conv2DTranspose(filters = 64, kernel_size = (3,3), strides=(2,2), padding='same')(layer_5)
    layer_6 = Conv2D(filters = 64, kernel_size = (3,3), padding='same',kernel_initializer = initializers.RandomNormal(0,0.8))(layer_6)
    layer_6 = BatchNormalization(momentum = 0.8)(layer_6)
    layer_6 = LeakyReLU(alpha=0.4)(layer_6)
    # (128, 128, 64)

    # final layer
    output_layer = Conv2D(filters = 3, kernel_size = (3,3), strides=(1,1), activation='tanh', padding='same')(layer_6)

    model = Model([latent_layer,label_layer_1], output_layer)
    return model

b = define_generator(512)
b.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_latent (InputLayer)      [(None, 512)]        0           []
#
#  dense_5 (Dense)                (None, 8192)         4202496     ['input_latent[0][0]']
#
#  input_label (InputLayer)       [(None, 1)]          0           []
#
#  activation (Activation)        (None, 8192)         0           ['dense_5[0][0]']
#
#  embedding_1 (Embedding)        (None, 1, 200)       1000        ['input_label[0][0]']
#
#  reshape_3 (Reshape)            (None, 8, 8, 128)    0           ['activation[0][0]']
#
#  dense_4 (Dense)                (None, 1, 64)        12864       ['embedding_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 8, 8, 128)   512         ['reshape_3[0][0]']
#  alization)
#
#  reshape_2 (Reshape)            (None, 8, 8, 1)      0           ['dense_4[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 8, 8, 129)    0           ['batch_normalization[0][0]',
#                                                                   'reshape_2[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 64)  74368       ['concatenate_2[0][0]']
#  ose)
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 64)   36928       ['conv2d_transpose[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  leaky_re_lu_5 (LeakyReLU)      (None, 16, 16, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 64)  36928       ['leaky_re_lu_5[0][0]']
#  spose)
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 64)   36928       ['conv2d_transpose_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  dense_6 (Dense)                (None, 1, 1024)      205824      ['embedding_1[0][0]']
#
#  leaky_re_lu_6 (LeakyReLU)      (None, 32, 32, 64)   0           ['batch_normalization_2[0][0]']
#
#  reshape_4 (Reshape)            (None, 32, 32, 1)    0           ['dense_6[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 32, 32, 65)   0           ['leaky_re_lu_6[0][0]',
#                                                                   'reshape_4[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 64)  37504       ['concatenate_3[0][0]']
#  spose)
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 64)   36928       ['conv2d_transpose_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  leaky_re_lu_7 (LeakyReLU)      (None, 64, 64, 64)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 64  36928      ['leaky_re_lu_7[0][0]']
#  spose)                         )
#
#  conv2d_8 (Conv2D)              (None, 128, 128, 64  36928       ['conv2d_transpose_3[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 64  256        ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  leaky_re_lu_8 (LeakyReLU)      (None, 128, 128, 64  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 128, 128, 3)  1731        ['leaky_re_lu_8[0][0]']
#
# ==================================================================================================
# Total params: 4,758,891
# Trainable params: 4,758,123
# Non-trainable params: 768
# __________________________________________________________________________________________________

# %%
# plot the generator model
tf.keras.utils.plot_model(b)

# %% [markdown]
# ## **Combine** or **GAN** Model

# %%
def define_gan(g_model, d_model):

  d_model.trainable = False

  g_latent, g_label = g_model.input
  g_output = g_model.output

  d_output = d_model([g_output,g_label])

  model = Model([g_latent, g_label], d_output)

  opt = Adam(learning_rate= 3e-4, beta_1=0.5)
  model.compile(loss='mse', optimizer=opt,  metrics=['accuracy'])
  
  return model
c = define_gan(b, a)
c.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_latent (InputLayer)      [(None, 512)]        0           []
#
#  dense_5 (Dense)                (None, 8192)         4202496     ['input_latent[0][0]']
#
#  input_label (InputLayer)       [(None, 1)]          0           []
#
#  activation (Activation)        (None, 8192)         0           ['dense_5[0][0]']
#
#  embedding_1 (Embedding)        (None, 1, 200)       1000        ['input_label[0][0]']
#
#  reshape_3 (Reshape)            (None, 8, 8, 128)    0           ['activation[0][0]']
#
#  dense_4 (Dense)                (None, 1, 64)        12864       ['embedding_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 8, 8, 128)   512         ['reshape_3[0][0]']
#  alization)
#
#  reshape_2 (Reshape)            (None, 8, 8, 1)      0           ['dense_4[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 8, 8, 129)    0           ['batch_normalization[0][0]',
#                                                                   'reshape_2[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 64)  74368       ['concatenate_2[0][0]']
#  ose)
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 64)   36928       ['conv2d_transpose[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  leaky_re_lu_5 (LeakyReLU)      (None, 16, 16, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 64)  36928       ['leaky_re_lu_5[0][0]']
#  spose)
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 64)   36928       ['conv2d_transpose_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  dense_6 (Dense)                (None, 1, 1024)      205824      ['embedding_1[0][0]']
#
#  leaky_re_lu_6 (LeakyReLU)      (None, 32, 32, 64)   0           ['batch_normalization_2[0][0]']
#
#  reshape_4 (Reshape)            (None, 32, 32, 1)    0           ['dense_6[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 32, 32, 65)   0           ['leaky_re_lu_6[0][0]',
#                                                                   'reshape_4[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 64)  37504       ['concatenate_3[0][0]']
#  spose)
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 64)   36928       ['conv2d_transpose_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  leaky_re_lu_7 (LeakyReLU)      (None, 64, 64, 64)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 64  36928      ['leaky_re_lu_7[0][0]']
#  spose)                         )
#
#  conv2d_8 (Conv2D)              (None, 128, 128, 64  36928       ['conv2d_transpose_3[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 64  256        ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  leaky_re_lu_8 (LeakyReLU)      (None, 128, 128, 64  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 128, 128, 3)  1731        ['leaky_re_lu_8[0][0]']
#
#  model (Functional)             (None, 1)            12286041    ['conv2d_9[0][0]',
#                                                                   'input_label[0][0]']
#
# ==================================================================================================
# Total params: 17,044,932
# Trainable params: 4,758,123
# Non-trainable params: 12,286,809
# __________________________________________________________________________________________________

# %%
# plot GAN model
tf.keras.utils.plot_model(c)

# %% [markdown]
# ## Load Dataset

# %%
def load_real_samples():
  # load dataset
  data = np.load("/content/drive/MyDrive/GAN_New_Approch/LSGAN/Abstract_128_combo.npz")
  data = data['a']
  data = np.array(data)
  X = data.astype('float32')
  # scale from [0,255] to [-1,1]
  X = (X - 127.5) / 127.5
  return X
# k = load_real_samples()
# print("image: ",k.shape)
# print("\nshape/size of the first 16 data: ",k[:16].shape)

# %% [markdown]
# ## Plot data with label

# %%
def save_plot(x_input,n=4):
    for i in range(n*n):
        plt.subplot(n, n, i+1)
        plt.imshow(x_input[i,:,:,:])
        plt.axis('off')
    plt.show()
# plot data
# save_plot(k[:16])

# %% [markdown]
# ## Generate real sample function

# %%
def generate_real_samples(dataset, n_samples):
	images = dataset
	ix = randint(0, images.shape[0], n_samples)
	X = images[ix]
	z = np.random.randint(0,5,size=(n_samples))
	y = ones((n_samples, 1))
	return [X,z], y
# d = generate_real_samples(k, 32)
# print("Generate real data as a batch randomly: ",d[0][0].shape)

# %% [markdown]
# ## Generate latent point function

# %%
def generate_latent_points(latent_dim, n_samples):
  x_input = randn(latent_dim * n_samples)
  z_input = x_input.reshape(n_samples, latent_dim)
  z = np.random.randint(0,5,size=(n_samples))
  return [z_input,z]
# p = generate_latent_points(512, 32)
# print("Generate latent point(with label) as a batch: ",p[0].shape)

# %% [markdown]
# ## Generate Fake samples of image with label

# %%
def generate_fake_samples(generator, latent_dim, n_samples):
	z_input,z = generate_latent_points(latent_dim, n_samples)
	images = generator.predict([z_input,z])
	y = zeros((n_samples, 1))
	return [images, z], y
# with tf.device(device_name):
	# kh = generate_fake_samples(b, 512, 32)
	# print("shape of the generated images: ",kh[0][0].shape)

# %% [markdown]
# ## Summarize the generator model

# %%
def summarize_the_model(generator,latent_dim = 100):
    latent_points = generate_latent_points(latent_dim= latent_dim, n_samples= 16)
    X  = generator.predict(latent_points)
    # scale from [-1,1] to [0,1]
    X = (X + 1) / 2.0
    save_plot(X, n=4)

# %%
def save_figure(generator,a,latent_dim = 512,n=4):
    latent_points, labels = generate_latent_points(latent_dim= latent_dim, n_samples= 16)
    X  = generator.predict([latent_points, labels])
    # plt.title("Epoch_"+str(a+1),loc = "center")
    for j in range(n*n):
        plt.subplot(n, n, j+1)
        plt.imshow(X[j,:,:,:])
        plt.axis('off')
    plt.suptitle("Epoch_"+str(a+1))
    plt.savefig("/content/drive/MyDrive/GAN_New_Approch/LSGAN/epoch_"+str(a+1))

# %% [markdown]
# ## Train function

# %%
def train(g_model, d_model, gan_model, dataset, latent_dim= 100, n_epochs=3, n_batch=128):

  print("No. of epoch: ",n_epochs)
  bat_per_epo = int(dataset.shape[0] / n_batch)
  print("batch per epoch: ", bat_per_epo)
  print("full batch: ",n_batch)
  half_batch = int(n_batch / 2)
  print("half batch: ", half_batch,'\n')
  print("*"*50,'\n\n')

  d_loss_real_array,d_loss_fake_array =[],[]
  g_loss_array = []
  for i in range(n_epochs):
    d_loss_r,d_loss_f = 0.0,0.0
    g_loss = 0.0
    
    for j in range(bat_per_epo):

      [X_real, labels_real], y_real = generate_real_samples(dataset, half_batch)
      d_loss1, _ = d_model.train_on_batch([X_real, labels_real], y_real)
      d_loss_r += d_loss1
      # print("real_loss")

      [X_fake, labels], y_fake = generate_fake_samples(g_model, latent_dim, half_batch)
      d_loss2, _ = d_model.train_on_batch([X_fake, labels], y_fake)
      d_loss_f += d_loss2
      # print("fake_loss")

      [z_input, labels_input] = generate_latent_points(latent_dim, n_batch)
      y_gan = ones((n_batch, 1))
      g_loss1,_ = gan_model.train_on_batch([z_input, labels_input], y_gan)
      g_loss += g_loss1

    d_loss_real_array.append(d_loss_r)
    d_loss_fake_array.append(d_loss_f)
    g_loss_array.append(g_loss)

    print('epoch -> [%d/%d], discriminator_loss_for_real_data = %.2f, discriminator_loss_for_fake_data = %.2f, generator_loss = %.2f\n' %(i+1, n_epochs, d_loss_r, d_loss_f, g_loss))
    if(i%20==0):
        summarize_the_model(g_model,latent_dim)
    # g_model.save("g_gan_model_"+str(i)+".h5")
    g_model.save("/content/drive/MyDrive/GAN_New_Approch/LSGAN/generator_model_4.h5")
    np.savez_compressed('/content/drive/MyDrive/GAN_New_Approch/LSGAN/loss_record_4.npz', a=d_loss_real_array, b=d_loss_fake_array, c=g_loss_array)
    # save_figure(g_model,i,latent_dim = 512,n=4)

    print("\n")

  return d_loss_real_array, d_loss_fake_array, g_loss_array

# %% [markdown]
# ## Main function

# %%
with tf.device(device_name):

  latent_dim = 512
  n_epochs = 150
  n_batch = 32
  d_model = define_discriminator()
  g_model = define_generator(latent_dim)
  gan_model = define_gan(g_model, d_model)
  dataset = load_real_samples()
  print('\nREADY TO GO !!!\n')
  
  d_loss_real_array, d_loss_fake_array, g_loss_array = train(g_model, d_model, gan_model, dataset, latent_dim, n_epochs, n_batch)
# Out:
# READY TO GO !!!
#
# No. of epoch:  150
# batch per epoch:  387
# full batch:  32
# half batch:  16
#
# **************************************************
#
#
# epoch -> [1/150], discriminator_loss_for_real_data = 80.37, discriminator_loss_for_fake_data = 36.03, generator_loss = 359.42
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [2/150], discriminator_loss_for_real_data = 75.09, discriminator_loss_for_fake_data = 45.50, generator_loss = 282.07
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [3/150], discriminator_loss_for_real_data = 71.48, discriminator_loss_for_fake_data = 41.65, generator_loss = 274.94
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [4/150], discriminator_loss_for_real_data = 78.51, discriminator_loss_for_fake_data = 52.53, generator_loss = 250.73
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [5/150], discriminator_loss_for_real_data = 79.88, discriminator_loss_for_fake_data = 53.45, generator_loss = 248.33
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [6/150], discriminator_loss_for_real_data = 81.57, discriminator_loss_for_fake_data = 46.61, generator_loss = 259.41
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [7/150], discriminator_loss_for_real_data = 71.65, discriminator_loss_for_fake_data = 43.83, generator_loss = 265.08
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [8/150], discriminator_loss_for_real_data = 78.57, discriminator_loss_for_fake_data = 54.87, generator_loss = 236.02
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [9/150], discriminator_loss_for_real_data = 76.01, discriminator_loss_for_fake_data = 49.38, generator_loss = 242.95
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [10/150], discriminator_loss_for_real_data = 71.77, discriminator_loss_for_fake_data = 47.14, generator_loss = 258.76
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [11/150], discriminator_loss_for_real_data = 69.79, discriminator_loss_for_fake_data = 44.15, generator_loss = 263.40
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [12/150], discriminator_loss_for_real_data = 72.45, discriminator_loss_for_fake_data = 48.21, generator_loss = 253.56
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [13/150], discriminator_loss_for_real_data = 71.73, discriminator_loss_for_fake_data = 48.66, generator_loss = 253.20
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [14/150], discriminator_loss_for_real_data = 75.96, discriminator_loss_for_fake_data = 50.14, generator_loss = 241.09
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [15/150], discriminator_loss_for_real_data = 71.67, discriminator_loss_for_fake_data = 48.52, generator_loss = 251.50
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [16/150], discriminator_loss_for_real_data = 73.70, discriminator_loss_for_fake_data = 47.81, generator_loss = 249.95
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [17/150], discriminator_loss_for_real_data = 70.53, discriminator_loss_for_fake_data = 44.35, generator_loss = 253.47
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [18/150], discriminator_loss_for_real_data = 68.34, discriminator_loss_for_fake_data = 45.03, generator_loss = 254.70
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [19/150], discriminator_loss_for_real_data = 69.63, discriminator_loss_for_fake_data = 44.67, generator_loss = 254.20
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [20/150], discriminator_loss_for_real_data = 66.70, discriminator_loss_for_fake_data = 41.91, generator_loss = 260.83
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [21/150], discriminator_loss_for_real_data = 67.13, discriminator_loss_for_fake_data = 39.47, generator_loss = 268.00
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [22/150], discriminator_loss_for_real_data = 62.10, discriminator_loss_for_fake_data = 36.54, generator_loss = 270.60
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [23/150], discriminator_loss_for_real_data = 65.43, discriminator_loss_for_fake_data = 40.18, generator_loss = 267.19
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [24/150], discriminator_loss_for_real_data = 61.78, discriminator_loss_for_fake_data = 37.31, generator_loss = 271.05
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [25/150], discriminator_loss_for_real_data = 57.02, discriminator_loss_for_fake_data = 33.80, generator_loss = 279.83
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [26/150], discriminator_loss_for_real_data = 56.75, discriminator_loss_for_fake_data = 33.79, generator_loss = 283.26
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [27/150], discriminator_loss_for_real_data = 56.20, discriminator_loss_for_fake_data = 34.86, generator_loss = 289.09
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [28/150], discriminator_loss_for_real_data = 53.95, discriminator_loss_for_fake_data = 32.31, generator_loss = 286.94
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [29/150], discriminator_loss_for_real_data = 55.05, discriminator_loss_for_fake_data = 34.73, generator_loss = 287.20
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [30/150], discriminator_loss_for_real_data = 55.92, discriminator_loss_for_fake_data = 35.28, generator_loss = 281.71
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [31/150], discriminator_loss_for_real_data = 56.96, discriminator_loss_for_fake_data = 35.79, generator_loss = 272.73
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [32/150], discriminator_loss_for_real_data = 56.81, discriminator_loss_for_fake_data = 35.63, generator_loss = 275.09
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [33/150], discriminator_loss_for_real_data = 53.20, discriminator_loss_for_fake_data = 33.57, generator_loss = 282.18
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [34/150], discriminator_loss_for_real_data = 52.29, discriminator_loss_for_fake_data = 31.81, generator_loss = 282.95
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [35/150], discriminator_loss_for_real_data = 51.50, discriminator_loss_for_fake_data = 31.31, generator_loss = 287.49
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [36/150], discriminator_loss_for_real_data = 53.13, discriminator_loss_for_fake_data = 32.35, generator_loss = 283.33
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [37/150], discriminator_loss_for_real_data = 50.97, discriminator_loss_for_fake_data = 33.29, generator_loss = 281.18
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [38/150], discriminator_loss_for_real_data = 50.75, discriminator_loss_for_fake_data = 30.51, generator_loss = 288.82
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [39/150], discriminator_loss_for_real_data = 51.34, discriminator_loss_for_fake_data = 31.05, generator_loss = 285.09
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [40/150], discriminator_loss_for_real_data = 48.99, discriminator_loss_for_fake_data = 29.64, generator_loss = 290.41
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [41/150], discriminator_loss_for_real_data = 53.39, discriminator_loss_for_fake_data = 30.08, generator_loss = 283.42
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [42/150], discriminator_loss_for_real_data = 46.87, discriminator_loss_for_fake_data = 29.16, generator_loss = 287.10
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [43/150], discriminator_loss_for_real_data = 45.21, discriminator_loss_for_fake_data = 27.32, generator_loss = 297.67
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [44/150], discriminator_loss_for_real_data = 45.33, discriminator_loss_for_fake_data = 27.23, generator_loss = 296.83
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [45/150], discriminator_loss_for_real_data = 45.80, discriminator_loss_for_fake_data = 26.96, generator_loss = 294.65
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [46/150], discriminator_loss_for_real_data = 43.19, discriminator_loss_for_fake_data = 26.35, generator_loss = 295.96
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [47/150], discriminator_loss_for_real_data = 45.50, discriminator_loss_for_fake_data = 26.14, generator_loss = 295.63
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [48/150], discriminator_loss_for_real_data = 43.12, discriminator_loss_for_fake_data = 24.27, generator_loss = 303.72
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [49/150], discriminator_loss_for_real_data = 41.08, discriminator_loss_for_fake_data = 23.67, generator_loss = 303.41
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [50/150], discriminator_loss_for_real_data = 42.94, discriminator_loss_for_fake_data = 24.93, generator_loss = 303.79
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [51/150], discriminator_loss_for_real_data = 41.92, discriminator_loss_for_fake_data = 23.73, generator_loss = 303.58
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [52/150], discriminator_loss_for_real_data = 39.60, discriminator_loss_for_fake_data = 22.93, generator_loss = 311.63
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [53/150], discriminator_loss_for_real_data = 38.47, discriminator_loss_for_fake_data = 21.44, generator_loss = 311.88
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [54/150], discriminator_loss_for_real_data = 40.67, discriminator_loss_for_fake_data = 23.45, generator_loss = 306.40
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [55/150], discriminator_loss_for_real_data = 39.78, discriminator_loss_for_fake_data = 22.06, generator_loss = 310.28
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [56/150], discriminator_loss_for_real_data = 39.31, discriminator_loss_for_fake_data = 23.29, generator_loss = 305.66
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [57/150], discriminator_loss_for_real_data = 38.97, discriminator_loss_for_fake_data = 22.49, generator_loss = 308.50
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [58/150], discriminator_loss_for_real_data = 38.94, discriminator_loss_for_fake_data = 20.83, generator_loss = 309.31
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [59/150], discriminator_loss_for_real_data = 38.54, discriminator_loss_for_fake_data = 22.39, generator_loss = 309.01
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [60/150], discriminator_loss_for_real_data = 38.16, discriminator_loss_for_fake_data = 20.61, generator_loss = 310.98
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [61/150], discriminator_loss_for_real_data = 37.91, discriminator_loss_for_fake_data = 21.18, generator_loss = 316.15
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [62/150], discriminator_loss_for_real_data = 36.82, discriminator_loss_for_fake_data = 20.27, generator_loss = 315.88
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [63/150], discriminator_loss_for_real_data = 34.78, discriminator_loss_for_fake_data = 19.09, generator_loss = 319.98
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [64/150], discriminator_loss_for_real_data = 36.73, discriminator_loss_for_fake_data = 21.06, generator_loss = 313.88
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [65/150], discriminator_loss_for_real_data = 34.99, discriminator_loss_for_fake_data = 19.22, generator_loss = 314.68
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [66/150], discriminator_loss_for_real_data = 35.12, discriminator_loss_for_fake_data = 19.14, generator_loss = 320.19
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [67/150], discriminator_loss_for_real_data = 34.94, discriminator_loss_for_fake_data = 19.38, generator_loss = 317.53
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [68/150], discriminator_loss_for_real_data = 34.88, discriminator_loss_for_fake_data = 18.51, generator_loss = 319.69
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [69/150], discriminator_loss_for_real_data = 35.02, discriminator_loss_for_fake_data = 18.69, generator_loss = 322.76
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [70/150], discriminator_loss_for_real_data = 34.39, discriminator_loss_for_fake_data = 18.53, generator_loss = 318.73
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [71/150], discriminator_loss_for_real_data = 32.51, discriminator_loss_for_fake_data = 16.64, generator_loss = 323.19
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [72/150], discriminator_loss_for_real_data = 33.62, discriminator_loss_for_fake_data = 17.62, generator_loss = 319.20
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [73/150], discriminator_loss_for_real_data = 34.78, discriminator_loss_for_fake_data = 18.12, generator_loss = 323.48
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [74/150], discriminator_loss_for_real_data = 32.22, discriminator_loss_for_fake_data = 17.63, generator_loss = 324.22
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [75/150], discriminator_loss_for_real_data = 32.67, discriminator_loss_for_fake_data = 17.63, generator_loss = 325.32
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [76/150], discriminator_loss_for_real_data = 32.33, discriminator_loss_for_fake_data = 16.62, generator_loss = 325.07
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [77/150], discriminator_loss_for_real_data = 33.95, discriminator_loss_for_fake_data = 17.34, generator_loss = 320.92
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [78/150], discriminator_loss_for_real_data = 32.53, discriminator_loss_for_fake_data = 16.42, generator_loss = 325.03
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [79/150], discriminator_loss_for_real_data = 33.30, discriminator_loss_for_fake_data = 16.10, generator_loss = 323.42
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [80/150], discriminator_loss_for_real_data = 31.26, discriminator_loss_for_fake_data = 15.64, generator_loss = 325.55
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [81/150], discriminator_loss_for_real_data = 31.55, discriminator_loss_for_fake_data = 15.92, generator_loss = 326.46
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [82/150], discriminator_loss_for_real_data = 30.70, discriminator_loss_for_fake_data = 15.30, generator_loss = 327.06
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [83/150], discriminator_loss_for_real_data = 30.41, discriminator_loss_for_fake_data = 15.33, generator_loss = 330.94
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [84/150], discriminator_loss_for_real_data = 30.51, discriminator_loss_for_fake_data = 15.25, generator_loss = 329.89
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [85/150], discriminator_loss_for_real_data = 29.84, discriminator_loss_for_fake_data = 14.90, generator_loss = 329.93
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [86/150], discriminator_loss_for_real_data = 29.76, discriminator_loss_for_fake_data = 15.83, generator_loss = 333.18
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [87/150], discriminator_loss_for_real_data = 30.30, discriminator_loss_for_fake_data = 15.21, generator_loss = 330.03
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [88/150], discriminator_loss_for_real_data = 29.57, discriminator_loss_for_fake_data = 14.23, generator_loss = 332.48
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [89/150], discriminator_loss_for_real_data = 29.66, discriminator_loss_for_fake_data = 14.23, generator_loss = 332.65
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [90/150], discriminator_loss_for_real_data = 29.07, discriminator_loss_for_fake_data = 13.76, generator_loss = 334.88
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [91/150], discriminator_loss_for_real_data = 29.25, discriminator_loss_for_fake_data = 14.56, generator_loss = 331.99
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [92/150], discriminator_loss_for_real_data = 28.23, discriminator_loss_for_fake_data = 13.86, generator_loss = 331.89
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [93/150], discriminator_loss_for_real_data = 28.66, discriminator_loss_for_fake_data = 13.92, generator_loss = 333.93
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [94/150], discriminator_loss_for_real_data = 27.89, discriminator_loss_for_fake_data = 12.55, generator_loss = 337.25
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [95/150], discriminator_loss_for_real_data = 28.56, discriminator_loss_for_fake_data = 13.06, generator_loss = 332.18
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [96/150], discriminator_loss_for_real_data = 27.61, discriminator_loss_for_fake_data = 13.44, generator_loss = 337.20
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [97/150], discriminator_loss_for_real_data = 26.89, discriminator_loss_for_fake_data = 13.20, generator_loss = 337.34
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [98/150], discriminator_loss_for_real_data = 28.26, discriminator_loss_for_fake_data = 12.94, generator_loss = 338.08
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [99/150], discriminator_loss_for_real_data = 28.30, discriminator_loss_for_fake_data = 13.39, generator_loss = 336.42
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [100/150], discriminator_loss_for_real_data = 28.94, discriminator_loss_for_fake_data = 12.73, generator_loss = 335.04
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [101/150], discriminator_loss_for_real_data = 27.36, discriminator_loss_for_fake_data = 12.55, generator_loss = 336.58
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [102/150], discriminator_loss_for_real_data = 27.94, discriminator_loss_for_fake_data = 13.10, generator_loss = 336.88
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [103/150], discriminator_loss_for_real_data = 26.53, discriminator_loss_for_fake_data = 12.36, generator_loss = 336.21
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [104/150], discriminator_loss_for_real_data = 26.02, discriminator_loss_for_fake_data = 12.30, generator_loss = 336.72
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [105/150], discriminator_loss_for_real_data = 26.42, discriminator_loss_for_fake_data = 11.82, generator_loss = 338.83
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [106/150], discriminator_loss_for_real_data = 24.73, discriminator_loss_for_fake_data = 10.78, generator_loss = 340.33
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [107/150], discriminator_loss_for_real_data = 26.72, discriminator_loss_for_fake_data = 12.29, generator_loss = 338.45
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [108/150], discriminator_loss_for_real_data = 26.58, discriminator_loss_for_fake_data = 11.58, generator_loss = 341.03
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [109/150], discriminator_loss_for_real_data = 27.09, discriminator_loss_for_fake_data = 12.04, generator_loss = 340.58
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [110/150], discriminator_loss_for_real_data = 27.30, discriminator_loss_for_fake_data = 11.77, generator_loss = 337.72
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [111/150], discriminator_loss_for_real_data = 25.01, discriminator_loss_for_fake_data = 11.23, generator_loss = 338.23
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [112/150], discriminator_loss_for_real_data = 25.34, discriminator_loss_for_fake_data = 11.47, generator_loss = 339.13
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [113/150], discriminator_loss_for_real_data = 26.49, discriminator_loss_for_fake_data = 11.49, generator_loss = 339.31
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [114/150], discriminator_loss_for_real_data = 26.89, discriminator_loss_for_fake_data = 12.31, generator_loss = 336.43
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [115/150], discriminator_loss_for_real_data = 27.28, discriminator_loss_for_fake_data = 11.34, generator_loss = 337.94
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [116/150], discriminator_loss_for_real_data = 25.16, discriminator_loss_for_fake_data = 11.96, generator_loss = 340.40
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [117/150], discriminator_loss_for_real_data = 24.01, discriminator_loss_for_fake_data = 10.21, generator_loss = 341.38
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [118/150], discriminator_loss_for_real_data = 26.08, discriminator_loss_for_fake_data = 11.05, generator_loss = 342.47
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [119/150], discriminator_loss_for_real_data = 24.33, discriminator_loss_for_fake_data = 11.08, generator_loss = 341.42
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [120/150], discriminator_loss_for_real_data = 25.05, discriminator_loss_for_fake_data = 10.46, generator_loss = 341.63
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [121/150], discriminator_loss_for_real_data = 24.70, discriminator_loss_for_fake_data = 10.96, generator_loss = 340.11
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [122/150], discriminator_loss_for_real_data = 24.71, discriminator_loss_for_fake_data = 10.55, generator_loss = 340.47
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [123/150], discriminator_loss_for_real_data = 24.54, discriminator_loss_for_fake_data = 10.54, generator_loss = 341.83
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [124/150], discriminator_loss_for_real_data = 24.54, discriminator_loss_for_fake_data = 10.29, generator_loss = 342.18
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [125/150], discriminator_loss_for_real_data = 24.72, discriminator_loss_for_fake_data = 10.69, generator_loss = 339.47
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [126/150], discriminator_loss_for_real_data = 24.36, discriminator_loss_for_fake_data = 10.60, generator_loss = 340.40
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [127/150], discriminator_loss_for_real_data = 24.92, discriminator_loss_for_fake_data = 10.56, generator_loss = 339.60
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [128/150], discriminator_loss_for_real_data = 24.14, discriminator_loss_for_fake_data = 10.60, generator_loss = 342.27
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [129/150], discriminator_loss_for_real_data = 25.10, discriminator_loss_for_fake_data = 10.50, generator_loss = 339.92
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [130/150], discriminator_loss_for_real_data = 23.94, discriminator_loss_for_fake_data = 10.40, generator_loss = 344.38
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [131/150], discriminator_loss_for_real_data = 23.53, discriminator_loss_for_fake_data = 10.03, generator_loss = 340.71
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [132/150], discriminator_loss_for_real_data = 24.63, discriminator_loss_for_fake_data = 9.61, generator_loss = 346.00
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [133/150], discriminator_loss_for_real_data = 24.40, discriminator_loss_for_fake_data = 10.51, generator_loss = 341.59
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [134/150], discriminator_loss_for_real_data = 24.58, discriminator_loss_for_fake_data = 10.34, generator_loss = 342.91
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [135/150], discriminator_loss_for_real_data = 24.27, discriminator_loss_for_fake_data = 9.39, generator_loss = 343.93
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [136/150], discriminator_loss_for_real_data = 23.59, discriminator_loss_for_fake_data = 9.98, generator_loss = 346.36
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [137/150], discriminator_loss_for_real_data = 24.36, discriminator_loss_for_fake_data = 9.52, generator_loss = 344.86
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [138/150], discriminator_loss_for_real_data = 24.22, discriminator_loss_for_fake_data = 10.17, generator_loss = 342.76
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [139/150], discriminator_loss_for_real_data = 23.75, discriminator_loss_for_fake_data = 9.93, generator_loss = 342.65
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [140/150], discriminator_loss_for_real_data = 23.02, discriminator_loss_for_fake_data = 9.55, generator_loss = 345.02
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [141/150], discriminator_loss_for_real_data = 23.34, discriminator_loss_for_fake_data = 9.24, generator_loss = 343.64
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [142/150], discriminator_loss_for_real_data = 23.69, discriminator_loss_for_fake_data = 10.21, generator_loss = 343.70
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [143/150], discriminator_loss_for_real_data = 23.71, discriminator_loss_for_fake_data = 9.58, generator_loss = 343.07
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [144/150], discriminator_loss_for_real_data = 23.88, discriminator_loss_for_fake_data = 9.39, generator_loss = 343.91
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [145/150], discriminator_loss_for_real_data = 24.18, discriminator_loss_for_fake_data = 10.06, generator_loss = 343.98
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [146/150], discriminator_loss_for_real_data = 23.83, discriminator_loss_for_fake_data = 10.07, generator_loss = 343.64
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [147/150], discriminator_loss_for_real_data = 24.24, discriminator_loss_for_fake_data = 9.26, generator_loss = 345.58
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [148/150], discriminator_loss_for_real_data = 23.43, discriminator_loss_for_fake_data = 9.27, generator_loss = 345.39
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [149/150], discriminator_loss_for_real_data = 23.84, discriminator_loss_for_fake_data = 9.65, generator_loss = 346.13
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
#
# epoch -> [150/150], discriminator_loss_for_real_data = 23.85, discriminator_loss_for_fake_data = 9.90, generator_loss = 343.37
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ## Plot Loss Values

# %%
loaded = np.load('/content/drive/MyDrive/GAN_New_Approch/LSGAN/loss_record_4.npz')
print(loaded['a'].shape)
print(loaded['b'].shape)
print(loaded['c'].shape)
# Out:
# (150,)
# (150,)
# (150,)

# %%
import matplotlib.pyplot as plot

d_loss_real_array = loaded['a']
d_loss_fake_array = loaded['b']

# %%
d_loss = np.array([(i+j) for i,j in zip(d_loss_real_array, d_loss_fake_array)])

# %%
g_loss = loaded['c']

# %%
plt.figure(figsize=(15,7))
plt.plot(d_loss)
plt.title('Discriminator Loss Graph')
plt.ylabel('Discriminator Loss')
plt.xlabel('epochs')
# plt.legend(["Discriminator Loss"], loc='upper right')
plt.savefig("/content/drive/MyDrive/GAN_New_Approch/LSGAN/Discriminator_Loss_Graph")
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(g_loss,color='orange')
plt.title('Generator Loss Graph')
plt.ylabel('Generator Loss')
plt.xlabel('epochs')
# plt.legend(["Generator Loss"], loc='upper right')
plt.savefig("/content/drive/MyDrive/GAN_New_Approch/LSGAN/Generator_Loss_Graph")
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(d_loss)
plt.plot(g_loss)
plt.title('Loss Graph')
plt.ylabel('Loss')
plt.xlabel('epochs')
# plt.legend(["Discriminator Loss", "Generator Loss"], loc='lower right')
plt.savefig("/content/drive/MyDrive/GAN_New_Approch/LSGAN/Loss_Graph")
plt.show()

# %% [markdown]
# # Prediction

# %%
generator = tensorflow.keras.models.load_model("/content/drive/MyDrive/GAN_New_Approch/LSGAN/generator_model_4.h5")
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
latent_dim = 512
n_samples = 16
z_input, labels = generate_latent_points(latent_dim, n_samples)
# print("latent points(latent points and labels): ",z_input.shape, labels.shape)
data = [z_input,labels]
pred = generator.predict(data)
pred = (pred + 1 ) / 2.0
# print("\nGenerated images with labels: ",pred.shape,'\n')
save_plot(pred,n=4)
# plt.imshow(pred[0])
# plt.show()

# %% [markdown]
#                                               -:END:-
